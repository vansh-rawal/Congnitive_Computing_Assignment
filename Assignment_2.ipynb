# %%
#Q1

roll_no=int(input("Enter your roll number:"))
digits=[int(x) for x in str(roll_no)]
l=[x*10 for x in digits]
print("l:",l)

l.append(100)
print("After append:",l)

l.insert(4,200)
print("After insert:",l)

l.remove(100)
print("After remove:",l)

l.pop()
print("After pop:",l)

l.sort()
print("Ascending:",l)

l.sort(reverse=True)
print("Descending:", l)

print("First 3 elements:",l[:3])
print("Last 3 elements:",l[-3:])

avg=sum(l)/len(l)

new_list = [x for x in l if x>avg]

print("Average:",avg)
print("Elements greater than average:",new_list)
# Out:
# Enter your roll number: 1024170325
# l: [10, 0, 20, 40, 10, 70, 0, 30, 20, 50]
# After append: [10, 0, 20, 40, 10, 70, 0, 30, 20, 50, 100]
# After insert: [10, 0, 20, 40, 200, 10, 70, 0, 30, 20, 50, 100]
# After remove: [10, 0, 20, 40, 200, 10, 70, 0, 30, 20, 50]
# After pop: [10, 0, 20, 40, 200, 10, 70, 0, 30, 20]
# Ascending: [0, 0, 10, 10, 20, 20, 30, 40, 70, 200]
# Descending: [200, 70, 40, 30, 20, 20, 10, 10, 0, 0]
# First 3 elements: [200, 70, 40]
# Last 3 elements: [10, 0, 0]
# Average: 40.0
# Elements greater than average: [200, 70]

# %%
#Q2

scores = tuple(l[:8])
print("Scores:",scores)

highest=max(scores)
highest_index=scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)

print("Highest score:",highest)
print("Highest index:",highest_index)
print("Lowest score:",lowest)
print("Lowest count:",lowest_count)

reversed_tuple=tuple(reversed(scores))
print("Reversed tuple:",reversed_tuple)

score = int(input("Enter a score:"))
if score in scores:
    print("First occurrence index:",scores.index(score))
else:
    print("Not present")

try:
    scores[0]=100
except TypeError as e:
    print(e)

first,second,*remaining=scores
print("First score:",first)
print("Second score:",second)
print("Remaining scores:",remaining)
# Out:
# Scores: (200, 70, 40, 30, 20, 20, 10, 10)
# Highest score: 200
# Highest index: 0
# Lowest score: 10
# Lowest count: 2
# Reversed tuple: (10, 10, 20, 20, 30, 40, 70, 200)
# Enter a score: 55
# Not present
# 'tuple' object does not support item assignment
# First score: 200
# Second score: 70
# Remaining scores: [40, 30, 20, 20, 10, 10]

# %%
#Q3

import random

roll_no=int(input("Enter your roll number: "))
random.seed(roll_no)
numbers=[random.randint(100, 900) for i in range(100)]
print("Numbers:",numbers)

odd=[x for x in numbers if x%2!=0]
print("Odd numbers:",odd)
print("Odd count:",len(odd))

even=[x for x in numbers if x%2==0]
print("Even numbers:",even)
print("Even count:",len(even))

def is_prime(n):
    if n<2:
        return False
        
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            return False
    return True

prime=[x for x in numbers if is_prime(x)]
print("Prime numbers:",prime)
print("Prime count:",len(prime))

count = {}
for x in numbers:
    if x in count:
        count[x]=count[x]+1
    else:
        count[x] =1

most_number=max(count,key=count.get)
print("Most frequent number =", most_number)
print("Number of times =", count[most_number])
# Out:
# Enter your roll number:  1024170325
# Numbers: [172, 310, 516, 140, 731, 210, 255, 887, 376, 761, 166, 300, 855, 310, 581, 196, 217, 357, 529, 282, 650, 432, 518, 513, 647, 323, 689, 745, 294, 681, 102, 181, 369, 844, 219, 656, 617, 236, 397, 881, 597, 528, 733, 450, 878, 665, 198, 366, 714, 359, 621, 340, 232, 661, 443, 765, 692, 413, 814, 273, 224, 358, 152, 823, 471, 723, 341, 567, 395, 287, 340, 410, 755, 260, 430, 773, 630, 453, 308, 164, 524, 838, 238, 202, 614, 780, 566, 860, 175, 416, 580, 241, 401, 487, 739, 623, 797, 251, 492, 437]
# Odd numbers: [731, 255, 887, 761, 855, 581, 217, 357, 529, 513, 647, 323, 689, 745, 681, 181, 369, 219, 617, 397, 881, 597, 733, 665, 359, 621, 661, 443, 765, 413, 273, 823, 471, 723, 341, 567, 395, 287, 755, 773, 453, 175, 241, 401, 487, 739, 623, 797, 251, 437]
# Odd count: 50
# ...

# %%
#Q4

roll_no=int(input("Enter your roll number:"))
digits=[int(x) for x in str(roll_no)]

A={x*7 for x in digits}
B={x*9 for x in digits}
print("A:",A)
print("B:",B)

print("Union:",A | B)
print("Intersection:",A & B)

print("A-B:",A-B)
print("B-A:",B-A)

print("Symmetric difference:",A^B)

print("A is subset of B:",A.issubset(B))
print("B is superset of A:",B.issuperset(A))

X=int(input("Enter a value:"))

A.discard(X)
print("A after discard =", A)
# Out:
# Enter your roll number: 1024170325
# A: {0, 35, 7, 14, 49, 21, 28}
# B: {0, 36, 9, 45, 18, 27, 63}
# Union: {0, 35, 36, 7, 9, 45, 14, 49, 18, 21, 27, 28, 63}
# Intersection: {0}
# A-B: {35, 7, 14, 49, 21, 28}
# B-A: {36, 9, 45, 18, 27, 63}
# Symmetric difference: {7, 9, 14, 18, 21, 27, 28, 35, 36, 45, 49, 63}
# A is subset of B: False
# B is superset of A: False
# Enter a value: 15
# A after discard = {0, 35, 7, 14, 49, 21, 28}

# %%
#Q5

my_dict={
    "name":"Vansh",
    "roll_no":"1024170325",
    "branch":"CSE",
    "age":18,
    "city":"Panipat"
}

city = my_dict.pop("city")
my_dict["location"]=city
my_dict["cgpa"]=8.5
my_dict["age"]=my_dict["age"] + 1
print(my_dict)

dict1=my_dict.copy()
dict1.pop("branch")
print(dict1)

dict2=my_dict.copy()
del dict2["branch"]
print(dict2)

for key,value in my_dict.items():
    print(key,":",value)

if "email" in my_dict:
    print(my_dict["email"])
else:
    print("email not found")

friend_dict ={
    "name":"Garv",
    "roll_no":"1024170323",
    "branch":"CSE",
    "age":18,
    "city":"Hisar"
}

merged_dict={**my_dict,**friend_dict}
print(merged_dict)

string_dict ={key:value for key,value in my_dict.items() if isinstance(value, str)}
print(string_dict)
# Out:
# {'name': 'Vansh', 'roll_no': '1024170325', 'branch': 'CSE', 'age': 19, 'location': 'Panipat', 'cgpa': 8.5}
# {'name': 'Vansh', 'roll_no': '1024170325', 'age': 19, 'location': 'Panipat', 'cgpa': 8.5}
# {'name': 'Vansh', 'roll_no': '1024170325', 'age': 19, 'location': 'Panipat', 'cgpa': 8.5}
# name : Vansh
# roll_no : 1024170325
# branch : CSE
# age : 19
# location : Panipat
# cgpa : 8.5
# email not found
# {'name': 'Garv', 'roll_no': '1024170323', 'branch': 'CSE', 'age': 18, 'location': 'Panipat', 'cgpa': 8.5, 'city': 'Hisar'}
# {'name': 'Vansh', 'roll_no': '1024170325', 'branch': 'CSE', 'location': 'Panipat'}
